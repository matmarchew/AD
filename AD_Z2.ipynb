# %% [markdown]
# ## Zadanie
#
# Wylosuj próbkę 1000-elementową liczb pseudolosowych zgodnie z modelem przedstawionym na wykładzie.

# %%
def random(x):
    a = 1140671485
    b = 128201163
    M = 2**24
    return ((a*x + b) % M)

y = [43645657]
for i in range(0, 1001):
    y.append(random(y[i]))
y.__delitem__(0)
print(y)
# Out:
# [15525184, 164363, 432042, 14389965, 11070820, 9173407, 7438574, 12904193, 11452616, 7671667, 429938, 5557109, 5366636, 13842311, 5596982, 7099433, 4135248, 11544027, 1109050, 8574237, 6317684, 6147695, 1262206, 10084945, 69336, 681283, 10604034, 7425989, 3249788, 9723479, 15807174, 16462201, 7061856, 10382763, 15291594, 1039213, 7771012, 14911295, 2709518, 6414753, 9064680, 13295379, 4956306, 11671573, 11828620, 3926311, 6935126, 4428489, 8117616, 11688315, 14733658, 9414077, 12874900, 9577487, 5554590, 3794161, 15959800, 12287203, 16058146, 4465765, 5478556, 6215671, 17894, 8550425, 12086656, 1108299, 8937962, 5190669, 6490532, 2008287, 7765806, 8318017, 2470152, 2178739, 13566386, 9729205, 13100972, 13773511, 3509622, 3465577, 11170192, 2039067, 11601530, 14386781, 11227828, 8260015, 11505854, 13498257, 4837144, 8463491, 4886594, 5245189, 682684, 11198871, 13281542, 1560249, 1763744, 8516843, 7061258, 105645, 3559364, 15028863, 6354510, 263905, 13164840, 10497619, 1618642, 6545749, 5513676, 4062311, 12621974, 2637833, 1234352, 1994939, 625562, 13530877, 14483668, 13205327, 2863070, 4069937, 4974392, 8608803, 2779490, 16580005, 1969372, 2128695, 5790758, 10696025, 14366144, 1675403, 1797162, 9377101, 12084708, 14651423, 15777134, 14233985, 12312904, 7319027, 11580402, 8936949, 2173932, 2579975, 1242038, 372393, 16583120, 14177371, 7495866, 13662109, 2195188, 1869039, 13704958, 7490769, 4312920, 15344579, 1872514, 11731525, 5668604, 6792407, 11624262, 830457, 4280800, 16759851, 2058570, 6266349, 11619332, 11886015, 3003534, 15100961, 4632936, 12041619, 2032914, 6941333, 16188940, 3559335, 3448534, 11873609, 11603440, 7653371, 7570906, 4819005, 4246804, 2038415, 11001374, 5410673, 7571320, 14515043, 11078562, 14292709, 8110364, 2645623, 14529126, 3945113, 9780736, 6059979, 16758378, 14366349, 15270436, 965471, 2112430, 1291969, 11620744, 10509619, 15443506, 7374645, 10334252, 1233223, 2988534, 2014185, 7791120, 1821595, 9763578, 10594525, 191284, 7946287, 12053822, 13034001, 2690968, 8741635, 5756098, 14302085, 5624636, 698391, 15029638, 1689913, 2030112, 5751659, 4477834, 6938413, 2590788, 9677055, 13628110, 4788577, 4440488, 5344467, 10393426, 275413, 14494284, 6611687, 386326, 2775689, 9864752, 16080699, 6209562, 4249981, 3135828, 13825487, 609374, 12010673, 11167672, 645795, 11595234, 1798181, 11318620, 11960759, 13650086, 9269209, 2524736, 1679115, 7684266, 7575501, 3464804, 15476383, 4520430, 7240705, 4587976, 15944819, 12572786, 9236597, 8221804, 13927559, 12943414, 12585257, 5765712, 2720475, 5821754, 9378333, 9410420, 13908847, 10746750, 767825, 4165592, 9626179, 3954434, 373957, 4745084, 13888343, 10914758, 8332921, 15983200, 13241003, 1736138, 6316141, 14222468, 12596287, 8868110, 7075489, 4584, 11377683, 14117266, 7519509, 4624012, 636455, 7629654, 13092809, 212592, 14694011, 735834, 16018109, 15345044, 2429199, 9435806, 11287025, 3180536, 4749795, 8523810, 67941, 15788444, 713975, 7347942, 14085401, 13569664, 9504331, 12323562, 9976077, 14416548, 12046815, 10418222, 2720065, 12186120, 11041715, 7162546, 1939893, 30892, 11302855, 1746550, 2725481, 14701200, 4291099, 16641914, 14207837, 492468, 7173807, 13978046, 8440977, 12931096, 5415299, 661826, 7695877, 7224252, 224919, 3473926, 8176569, 2720, 9867755, 14805002, 8593837, 377028, 8060799, 9695054, 9378785, 12296744, 781139, 621522, 16090709, 7549644, 6605159, 12595606, 13464841, 3618480, 7687611, 12121242, 10763261, 11514324, 5598287, 8120542, 7434033, 4581432, 14244131, 6058594, 13296293, 8936924, 6654007, 16594214, 5810777, 13555392, 175499, 1316138, 8985165, 1988324, 11648287, 7222894, 8701569, 5055048, 16771827, 3407090, 6456053, 6733036, 14330631, 7146678, 10183593, 5237456, 10727771, 12863930, 12500125, 11186164, 8712687, 9164798, 6693329, 16404568, 303299, 72578, 6907717, 479228, 14234071, 13678662, 5415161, 8614624, 16603435, 14324298, 1188589, 15580420, 264895, 3526030, 15892769, 11956840, 11303571, 7654930, 13406101, 10688268, 11934887, 2701270, 8086089 ...

# %% [markdown]
# ## Zadanie
# Wylosuj próbkę 1000-elementową z rozkładu jednostajnego na odcinku (wykorzystując kod z Zad 1.).

# %%
def random(x):
    a = 1140671485
    b = 128201163
    M = 2**24
    return ((a*x + b) % M) / float(M)

y = [43645657]
for i in range(0, 1001):
    y.append(random(y[i]))
y.__delitem__(0)
print(y)
# Out:
# [0.9253730773925781, 0.5568698268182288, 0.5025848930145429, 0.8117892297187339, 0.8343814116879926, 0.3704084710203972, 0.8252043542513832, 0.7464665885204838, 0.3931395429697133, 0.3706744486978124, 0.8432879953199617, 0.975961023825036, 0.9963098376169341, 0.37981182304723404, 0.4645318517592969, 0.2245888814972119, 0.9110298139997539, 0.5816811212523589, 0.18948789688308665, 0.5245377854798647, 0.30435143124632447, 0.3340312267315575, 0.35194030000313603, 0.5695659897281331, 0.36578835896756345, 0.5110860836055053, 0.38977938587223804, 0.142219657020199, 0.31080236252671867, 0.772625649265084, 0.17167626001194236, 0.3135367302339347, 0.9585334466687847, 0.8114207407147234, 0.8093280953683504, 0.6670505640529285, 0.9936981480325215, 0.2022448276285047, 0.3918728151664439, 0.28455048841465214, 0.9877786146054603, 0.799779783085171, 0.017867317482220813, 0.8561715224630397, 0.8519032563344524, 0.5617067503544888, 0.8314440286981508, 0.17069780287160086, 0.24701209591545137, 0.4355688846612189, 0.2554164818707889, 0.0069773595946038824, 0.1157707053515793, 0.5125561590721261, 0.4897288152395731, 0.937713261044891, 0.3958705055873679, 0.5563507363822282, 0.4672922879433514, 0.412269056879893, 0.6712770659170815, 0.28105513012886973, 0.7501315862516229, 0.6423202416327172, 0.3123003762215575, 0.8744745797337679, 0.09631564972805506, 0.1898201825642829, 0.5471296625478104, 0.8403577605461905, 0.776736358016592, 0.4511605472730196, 0.3154829997615778, 0.09085898579916929, 0.8188253198344917, 0.3127603847509377, 0.9057502462281875, 0.22272690559758246, 0.7844353412061444, 0.9746091687735614, 0.9043981337281366, 0.13079769795550078, 0.5342311478544772, 0.9633965347064191, 0.14205878302009012, 0.2998646488677821, 0.028977949799092073, 0.6115758436671381, 0.2220097056580954, 0.7356734059710845, 0.6593184151676255, 0.4679946134747155, 0.46001969124107234, 0.9178101621386645, 0.042672371554445476, 0.5426502483773881, 0.535805443063623, 0.07043179335986594, 0.42999442356892814, 0.8764126702599668, 0.22808510412286864, 0.148735608232748, 0.753817445947341, 0.892919331053541, 0.3503617249756701, 0.46223974914307675, 0.0687503863013319, 0.31567670325421915, 0.10402875428762925, 0.7142289063912735, 0.20132149954199008, 0.32909636765650774, 0.01642259376374966, 0.7579457411794692, 0.1735993111497649, 0.44428366685982823, 0.8479285859015917, 0.29147161569110835, 0.45834134255205683, 0.8037003782837644, 0.28442591381092797, 0.979308872174812, 0.22392776592481312, 0.866081016671, 0.5256430158865157, 0.37949529356661316, 0.44301122803327786, 0.7614163370366498, 0.40956275885437776, 0.4872777070474612, 0.7710640850795798, 0.0655065749818462, 0.09513218175210625, 0.10935700121313019, 0.07649278455543573, 0.8420770854135711, 0.8936320843201884, 0.3988213339540039, 0.7569755465384986, 0.10763643853401561, 0.9595129002753975, 0.8780131240960714, 0.33689887000053886, 0.5469094120464675, 0.8253830790234176, 0.7586179640003508, 0.21930328273514732, 0.5516655554101106, 0.14875002580885166, 0.7547976871234852, 0.9595652607507219, 0.8815730771385546, 0.5789376518520442, 0.002961281566868479, 0.8427202965249414, 0.9373635695424838, 0.37209521859440997, 0.939885172574833, 0.5435372907171256, 0.596114847372796, 0.17082710166427972, 0.2558030327343914, 0.03325868944179433, 0.9026204153731676, 0.009931838216061806, 0.31664369384616364, 0.1697737857931152, 0.1841888043108355, 0.16425609192938495, 0.8090445578925625, 0.6477730442570291, 0.6830327114842021, 0.08031346274979967, 0.10184239270127904, 0.5655796717715944, 0.09476131710512448, 0.08414216654647788, 0.36215335522224024, 0.2639446556022875, 0.5868020810887131, 0.5376584670873186, 0.19641763420792557, 0.9956859047497062, 0.3373910525093038, 0.5803725654781182, 0.10052008135228618, 0.47567662408549083, 0.9823143586745005, 0.4282687453070366, 0.759084980992327, 0.2510554498263886, 0.7104737622028416, 0.9460118046672505, 0.960082832415253, 0.9167624219723223, 0.9714372315028612, 0.6887402798329276, 0.468367146 ...

# %% [markdown]
# ## Zadanie
# Wylosuj próbkę 1000-elementową z rozkładu normalnego za pomocą metody odwrotnej do dystrybuanty http://staff.iiar.pwr.wroc.pl/grzegorz.mzyk/kmi/kmi03.pdf.

# %% [markdown]
# ## Zadanie
#
# Wylosuj próbkę 1000-elementową z rozkładów
#
#   * N(0,1^2)
#   * N(3,3^2)
#   * Unif(0,1)
#   * Unif(-1,1)
#   * Gamma(1,2)
#   * LogN(.08,2^2)
#
# i narysuj histogram

# %%
import numpy as np
import numpy.random as rnd
import matplotlib.pyplot as plt
import scipy.stats as stats
from numpy import linalg as LA
import scipy.stats as stats

x = rnd.rand(100)
plt.plot(x)
plt.show()

x = rnd.randn(1000)
plt.hist(x, bins = 30)
plt.show()

# %%
import numpy.random as rnd
import matplotlib.pyplot as plt

f = rnd.lognormal(0.08, 2, 1000)

plt.hist(f, bins=[0.1, 0.2, 0.4, 0.8, 1.6, 3.2, 6.4, 12.8, 25.6, 51.2, 100])
plt.axis([0, 100, 0, 200])
plt.show()

a = rnd.normal(0, 1, 1000)
b = rnd.normal(3, 3, 1000)
c = rnd.uniform(0, 1, 1000)
d = rnd.uniform(-1, 1, 1000)
e = rnd.gamma(1, 2, 1000)

# %% [markdown]
# ## Zadanie
# Narysuj histogram oraz gęstość rozkładu LogN

# %%
x = rnd.randn(1000)
plt.hist(x, bins = 30, normed=1)
pdfx = np.linspace(-5, 5, 200)
pdfy = stats.norm.pdf(pdfx)
plt.plot(pdfx, pdfy, 'r-', label='PDF')
plt.show()

# %% [markdown]
# ## Zadanie
#
# Wylosuj próbkę z dwuwymiarowego rozkładu normalnego

# %%
y = rnd.uniform(1, 5, (5000,2))
plt.scatter(y[:,0],y[:,1])
plt.show()

# %% [markdown]
# ## Zadanie
#
# Narysuj wykres 3d gęstości dwuwymiarowego rozkładu normalnego.

# %% [markdown]
# ## Zadanie
#
# Prosze narysować poziomicę dwuwymiarowego rozkładu normalnego.

# %% [markdown]
# ## Zadanie
# Pobierz dowolne zdjęcie i narysuj histogram z danych dla każdego z komponentów RGB.

# %% [markdown]
# ## Zadanie
# Pobierz dowolny plik z dźwiękiem i narysuj histogram pliki.

# %% [markdown]
# ## Zadanie
# Niech $X = (x_1, \ldots , x_N )$, $Y = (y_1, \ldots , y_K)$. Znamy srednią i wariancję $X$ oraz
# $Y$. Proszę wyliczyć srednią i wariancję $X \cup Y = (x_1, \ldots , x_N , y_1, \ldots , y_K)$.

# %% [markdown]
# # Zadanie
#
# Proszę policzyć medianę $X = \{1, 2, 5, 2, 3\}$.

# %% [markdown]
# ## Przykład
# Użyj testu kstest do obliczenia wartości p-value.

# %%
x = rnd.randn(1000)
plt.hist(x)
plt.show()
kstest = stats.kstest
stat, pval = kstest(x, 'norm')
print(stat)
print(pval)
if(pval < 0.05):
    print("Odrzucam hipotezę zerową na poziomie istotności 0.05")
else:    
    print("Nie ma podstaw by odrzucić hipotezę zerową  na poziomie istotności 0.05")
# Out:
# 0.0232786313478
# 0.650538654971
# Nie ma podstaw by odrzucić hipotezę zerową  na poziomie istotności 0.05
